# %%
tokens = []
labels = []
with open('./output/kw_result_output/token_test.txt', 'r') as f:
    for line in f.readlines():
        tokens.append(line)
with open('./output/kw_result_output/label_test.txt', 'r') as f:
    for line in f.readlines():
        labels.append(line)

# %%
for token, label in zip(tokens, labels):
    print(token.replace('\n',''), label)
# Out:
# [CLS] [CLS]
#
# 昨 O
#
# 年 O
#
# ▁10 O
#
# 月 O
#
# に X
#
# は X
#
# 、 X
#
# 34 X
#
# 人 X
#
# が X
#
# 、 X
#
# 今回 X
#
# の X
#
# 現場 X
#
# に X
#
# 近い X
#
# エジプト O
#
# の X
#
# タ O
#
# バ O
#
# で X
#
# 爆発 X
#
# 事件 X
#
# の X
#
# ため X
#
# 死亡 X
#
# し X
#
# て X
#
# いる X
#
# 。 X
#
# [SEP] [SEP]
#
# [CLS] [CLS]
#
# タ O
#
# バ O
#
# は X
#
# イスラエル O
#
# から X
#
# の X
#
# 観光 X
#
# 客 X
#
# に X
#
# 人気 X
#
# の X
#
# ▁ある X
#
# リゾート X
#
# 地 X
#
# で X
#
# ▁ある X
#
# 。 X
#
# [SEP] [SEP]
#
# [CLS] [CLS]
#
# ▁この X
#
# ため X
#
# 、 X
#
# 当局 X
#
# は X
#
# 今回 X
#
# の X
#
# 爆発 X
#
# は X
#
# イスラエル O
#
# ・ X
#
# パレスチナ O
#
# 間 X
#
# の X
#
# 緊張 X
#
# に X
#
# か X
#
# かわ X
#
# る X
#
# もの X
#
# として X
#
# 非難 X
#
# し X
#
# て X
#
# いる X
#
# 。 X
#
# [SEP] [SEP]
#
# [CLS] [CLS]
#
# 地元 X
#
# の X
#
# 警察 X
#
# に X
#
# よ X
#
# れ X
#
# ば X
#
# 少なくとも X
#
# 30 X
#
# 人 X
#
# が X
#
# 死亡 X
#
# 、 X
#
# ▁100 X
#
# 人 X
#
# 以上 X
#
# が X
#
# 負傷 X
#
# し X
#
# た X
#
# 。 X
#
# [SEP] [SEP]
#
# [CLS] [CLS]
#
# bbc O
#
# の X
#
# 報道 X
#
# に X
#
# よ X
# ...

# %%
res = {'words': ['▁', '昨', '年', '▁10', '月には', '、', '34', '人が', '、', '今回の', '現場', 'に近い', 'エジプト', 'の', 'タ', 'バ', 'で', '爆発', '事件', 'のため', '死亡', 'している', '。'], 'labels': [3, 2, 2, 2, 1, 1, 1, 1, 1, 1, 1, 1, 2, 1, 2, 2, 1, 1, 1, 1, 1, 1, 1, 4, 0, 0, 0, 0, 0, 0, 0, 0]}

# %%
for word, label in zip(res['words'], res['labels']):
    print(word, label)
# Out:
# ▁ 3
# 昨 2
# 年 2
# ▁10 2
# 月には 1
# 、 1
# 34 1
# 人が 1
# 、 1
# 今回の 1
# 現場 1
# に近い 1
# エジプト 2
# の 1
# タ 2
# バ 2
# で 1
# 爆発 1
# 事件 1
# のため 1
# 死亡 1
# している 1
# 。 1
